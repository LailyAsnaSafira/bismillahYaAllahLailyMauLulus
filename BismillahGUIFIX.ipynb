# %%
import tkinter
import numpy as np
from datetime import datetime
from tkinter import ttk
from tkinter import scrolledtext as tkst
from tkinter import messagebox as mb
from tkinter.filedialog import askopenfilename
from matplotlib.backend_bases import key_press_handler
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg, NavigationToolbar2Tk
from matplotlib.figure import Figure
import serial.tools.list_ports
import threading
from tkinter import *
import serial
import datetime as dt
import csv
import time

arrayposisi = []

# %%
font9 = "-family {Showcard Gothic} -size 14 -weight bold " \
        "-slant roman -underline 0 -overstrike 0"

# ------------------------------------------------Make a Tkinter Canvas---------------------------------------------------
windows = tkinter.Tk()
windows.title("GUI Adaptif Kontrol Eksoskeleton")
windows.configure(background="#e2e6e2")
windows.geometry("+250+10")

# ---------------------------------------------------------Declare Attribute--------------------------------------------------------
Title = tkinter.Label(windows, text="GUI Eksoskeleton", font=font9,
                      bg='#e2e6e2')
Title.pack(pady=10, expand=tkinter.YES, side=tkinter.TOP)
part_1 = tkinter.Frame(windows, background='#e2e6e2')
part_1.pack()

#------------------------------------------------------connect to exoskeleton------------------------------------------------------
my_frame_1 = tkinter.LabelFrame(part_1, width=250, height=100, text='''Connect to Exoskeleton''', relief='groove', foreground="black",
                                background='#e2e6e2')
my_frame_1.pack(padx=5, side=tkinter.LEFT)
my_frame_1.pack_propagate(0)

def connect_check(args):
    if "-" in clicked_bd.get():
        connect_btn["state"] = "disable"
    else:
        connect_btn["state"] = "active"

def baud_select():
    global clicked_bd, drop_bd
    clicked_bd = StringVar()
    bds = ["-",
           "9600",
           "56000",
           "115200"]
    clicked_bd.set(bds[0])
    drop_bd = OptionMenu(my_frame_1, clicked_bd, *bds, command=connect_check)
    drop_bd.config(width=7)
    drop_bd.grid(column=2, row=3, padx=10)

def update_coms():
    global clicked_com, drop_COM
    ports = serial.tools.list_ports.comports()
    coms = [com[0] for com in ports]
    coms.insert(0, "-")
    try:
        drop_COM.destroy()
    except:
        pass
    clicked_com = StringVar()
    clicked_com.set(coms[0])
    drop_COM = OptionMenu(my_frame_1, clicked_com, *coms, command=connect_check)
    drop_COM.config(width=7)
    drop_COM.grid(column=2, row=2, padx=10)
    connect_check(0)

def connexion():
    global  serialData, arduino
    if connect_btn["text"] in "Disconnect":
        serialData = False
        connect_btn["text"] = "Connect"
        refresh_btn["state"] = "active"
        drop_bd["state"] = "active"
        drop_COM["state"] = "active"

    else:
        serialData = True
        connect_btn["text"] = "Disconnect"
        refresh_btn["state"] = "disable"
        drop_bd["state"] = "disable"
        drop_COM["state"] = "disable"
        port = clicked_com.get()
        baud = clicked_bd.get()
        try:
            arduino = serial.Serial(port, baud, timeout=.1)
        except:
            pass
        t1 = threading.Thread(target=readSerial)
        t1.deamon = True
        t1.start()      
#========================================================Read Data Exoskeleton ==================================================
my_frame_3 = tkinter.LabelFrame(part_1, width=400, height=200, text='''Read Data Exoskeleton''', relief='groove',
                                foreground="black", background='#e2e6e2')
my_frame_3.pack(side=tkinter.LEFT)
my_frame_3.pack_propagate(0)
my_frame_3_bantuan1 = tkinter.Frame(my_frame_3, width=85, height=50, background='#e2e6e2')
my_frame_3_bantuan1.pack(side=tkinter.LEFT)
my_frame_3_bantuan2 = tkinter.Frame(my_frame_3, width=65, height=50, background='#e2e6e2')
my_frame_3_bantuan2.pack(side=tkinter.LEFT)
my_frame_3_bantuan3 = tkinter.Frame(my_frame_3, width=50, height=50, background='#e2e6e2')
my_frame_3_bantuan3.pack(side=tkinter.LEFT)
my_frame_3_bantuan4 = tkinter.Frame(my_frame_3, width=80, height=50, background='#e2e6e2')
my_frame_3_bantuan4.pack(side=tkinter.LEFT)
my_frame_3_bantuan5 = tkinter.Frame(my_frame_3, width=65, height=50, background='#e2e6e2')
my_frame_3_bantuan5.pack(side=tkinter.LEFT)
my_frame_3_bantuan7 = tkinter.Frame(my_frame_3_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_3_bantuan7.pack()
my_frame_3_bantuan7.pack_propagate(0)
my_frame_3_bantuan8 = tkinter.Frame(my_frame_3_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_3_bantuan8.pack()
my_frame_3_bantuan8.pack_propagate(0)
my_frame_3_bantuan9 = tkinter.Frame(my_frame_3_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan9.pack()
my_frame_3_bantuan9.pack_propagate(0)
my_frame_3_bantuan10 = tkinter.Frame(my_frame_3_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan10.pack()
my_frame_3_bantuan10.pack_propagate(0)
my_frame_3_bantuan13 = tkinter.Frame(my_frame_3_bantuan4, width=35, height=25, background='#e2e6e2')
my_frame_3_bantuan13.pack()
my_frame_3_bantuan13.pack_propagate(0)
my_frame_3_bantuan14 = tkinter.Frame(my_frame_3_bantuan4, width=35, height=25, background='#e2e6e2')
my_frame_3_bantuan14.pack()
my_frame_3_bantuan14.pack_propagate(0)
my_frame_3_bantuan15 = tkinter.Frame(my_frame_3_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan15.pack()
my_frame_3_bantuan15.pack_propagate(0)
my_frame_3_bantuan16 = tkinter.Frame(my_frame_3_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan16.pack()
my_frame_3_bantuan16.pack_propagate(0)
my_frame_3_bantuan19 = tkinter.Frame(my_frame_3_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_3_bantuan19.pack()
my_frame_3_bantuan19.pack_propagate(0)
my_frame_3_bantuan20 = tkinter.Frame(my_frame_3_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan20.pack()
my_frame_3_bantuan20.pack_propagate(0)
my_frame_3_bantuan21 = tkinter.Frame(my_frame_3_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_3_bantuan21.pack()
my_frame_3_bantuan22 = tkinter.Frame(my_frame_3_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_3_bantuan22.pack()
my_frame_3_bantuan23 = tkinter.Frame(my_frame_3_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_3_bantuan23.pack()
my_frame_3_bantuan24 = tkinter.Frame(my_frame_3_bantuan4, width=35, height=25, background='#e2e6e2')
my_frame_3_bantuan24.pack()
my_frame_3_bantuan24.pack_propagate(0)
my_frame_3_bantuan25 = tkinter.Frame(my_frame_3_bantuan4, width=35, height=25, background='#e2e6e2')
my_frame_3_bantuan25.pack()
my_frame_3_bantuan25.pack_propagate(0)
my_frame_3_bantuan26 = tkinter.Frame(my_frame_3_bantuan4, width=35, height=25, background='#e2e6e2')
my_frame_3_bantuan26.pack()
my_frame_3_bantuan26.pack_propagate(0)
my_frame_3_bantuan27 = tkinter.Frame(my_frame_3_bantuan4, width=80, height=25, background='#e2e6e2')
my_frame_3_bantuan27.pack()
my_frame_3_bantuan27.pack_propagate(0)
my_frame_3_bantuan28 = tkinter.Frame(my_frame_3_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan28.pack()
my_frame_3_bantuan28.pack_propagate(0)
my_frame_3_bantuan29 = tkinter.Frame(my_frame_3_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan29.pack()
my_frame_3_bantuan29.pack_propagate(0)
my_frame_3_bantuan30 = tkinter.Frame(my_frame_3_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan30.pack()
my_frame_3_bantuan30.pack_propagate(0)
my_frame_3_bantuan31 = tkinter.Frame(my_frame_3_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan31.pack()
my_frame_3_bantuan31.pack_propagate(0)
my_frame_3_bantuan32 = tkinter.Frame(my_frame_3_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan32.pack()
my_frame_3_bantuan32.pack_propagate(0)
my_frame_3_bantuan33 = tkinter.Frame(my_frame_3_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan33.pack()
my_frame_3_bantuan33.pack_propagate(0)
my_frame_3_bantuan34 = tkinter.Frame(my_frame_3_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_3_bantuan34.pack()
my_frame_3_bantuan34.pack_propagate(0)

my_frame_3_text1 = tkinter.Label(my_frame_3_bantuan7, text='Kecepatan', background='#e2e6e2')
my_frame_3_text1.pack(side=tkinter.LEFT)
my_frame_3_text2 = tkinter.Label(my_frame_3_bantuan8, text='Sudut', background='#e2e6e2')
my_frame_3_text2.pack(side=tkinter.LEFT)
my_frame_3_text13 = tkinter.Label(my_frame_3_bantuan19, text='Koreksi', background='#e2e6e2')
my_frame_3_text13.pack(side=tkinter.LEFT)
my_frame_3_text14 = tkinter.Label(my_frame_3_bantuan21, text='Force', background='#e2e6e2')
my_frame_3_text14.pack(side=tkinter.LEFT)
my_frame_3_text15 = tkinter.Label(my_frame_3_bantuan22, text='S', background='#e2e6e2')
my_frame_3_text15.pack(side=tkinter.LEFT)
my_frame_3_text16 = tkinter.Label(my_frame_3_bantuan23, text='Anu', background='#e2e6e2')
my_frame_3_text16.pack(side=tkinter.LEFT)

my_frame_3_text5 = tkinter.Label(my_frame_3_bantuan13, text='P', background='#e2e6e2')
my_frame_3_text5.pack(side=tkinter.LEFT)
my_frame_3_text6 = tkinter.Label(my_frame_3_bantuan14, text='I', background='#e2e6e2')
my_frame_3_text6.pack(side=tkinter.LEFT)
my_frame_3_text17 = tkinter.Label(my_frame_3_bantuan24, text='P', background='#e2e6e2')
my_frame_3_text17.pack(side=tkinter.LEFT)
my_frame_3_text18 = tkinter.Label(my_frame_3_bantuan25, text='I', background='#e2e6e2')
my_frame_3_text18.pack(side=tkinter.LEFT)
my_frame_3_text19 = tkinter.Label(my_frame_3_bantuan26, text='P', background='#e2e6e2')
my_frame_3_text19.pack(side=tkinter.LEFT)
my_frame_3_text20= tkinter.Label(my_frame_3_bantuan27, text='Defuzzifikasi', background='#e2e6e2')
my_frame_3_text20.pack(side=tkinter.LEFT)


my_frame_3_spinbox1 = tkinter.Entry(my_frame_3_bantuan9, from_=None, to=None, width=4)
my_frame_3_spinbox1.configure(justify=tkinter.CENTER)
my_frame_3_spinbox1.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox2 = tkinter.Entry(my_frame_3_bantuan10, from_=None, to=None, width=4)
my_frame_3_spinbox2.configure(justify=tkinter.CENTER)
my_frame_3_spinbox2.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox5 = tkinter.Entry(my_frame_3_bantuan20, from_=None, to=None, width=4)
my_frame_3_spinbox5.configure(justify=tkinter.CENTER)
my_frame_3_spinbox5.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox6 = tkinter.Entry(my_frame_3_bantuan28, from_=None, to=None, width=4)
my_frame_3_spinbox6.configure(justify=tkinter.CENTER)
my_frame_3_spinbox6.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox7 = tkinter.Entry(my_frame_3_bantuan29, from_=None, to=None, width=4)
my_frame_3_spinbox7.configure(justify=tkinter.CENTER)
my_frame_3_spinbox7.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox8 = tkinter.Entry(my_frame_3_bantuan30, from_=None, to=None, width=4)
my_frame_3_spinbox8.configure(justify=tkinter.CENTER)
my_frame_3_spinbox8.pack(pady=1, side=tkinter.LEFT)

my_frame_3_spinbox3 = tkinter.Entry(my_frame_3_bantuan15, from_=None, to=None, width=4)
my_frame_3_spinbox3.configure(justify=tkinter.CENTER)
my_frame_3_spinbox3.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox4 = tkinter.Entry(my_frame_3_bantuan16, from_=None, to=None, width=4)
my_frame_3_spinbox4.configure(justify=tkinter.CENTER)
my_frame_3_spinbox4.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox9 = tkinter.Entry(my_frame_3_bantuan31, from_=None, to=None, width=4)
my_frame_3_spinbox9.configure(justify=tkinter.CENTER)
my_frame_3_spinbox9.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox10 = tkinter.Entry(my_frame_3_bantuan32, from_=None, to=None, width=4)
my_frame_3_spinbox10.configure(justify=tkinter.CENTER)
my_frame_3_spinbox10.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox11 = tkinter.Entry(my_frame_3_bantuan33, from_=None, to=None, width=4)
my_frame_3_spinbox11.configure(justify=tkinter.CENTER)
my_frame_3_spinbox11.pack(pady=1, side=tkinter.LEFT)
my_frame_3_spinbox12 = tkinter.Entry(my_frame_3_bantuan34, from_=None, to=None, width=4)
my_frame_3_spinbox12.configure(justify=tkinter.CENTER)
my_frame_3_spinbox12.pack(pady=1, side=tkinter.LEFT)

def readSerial():
    global serialData, arrayposisi
    
    
    while serialData:
        # data = arduino.readline()
        # sensor = str(data.decode('utf8'))
        # f = open("Bismillahhhhhhh.csv", "a+")
        # row = sensor.split(',')
    
        # writer = csv.writer(f, delimiter=',')
        # waktu = dt.datetime.now().strftime('%H:%M:%S.%f')
        # row.insert(0, waktu)
        # writer.writerow(row)
        # f.flush()
        data = arduino.readline()
        f = open("Bismillaaaaaah.csv", "a+")

       #writer = csv.writer(f, delimiter=',')
        if len(data)>0:
            try:
                sensor = data.decode('utf8')
                string = sensor.rstrip() # remove \n and \r
                if string != "":
                    writer = csv.writer(f, delimiter=',')
                    readOut = arduino.readline().decode('utf8')
                    string = readOut.rstrip() # remove \n and \r
                    rows = [float(x) for x in string.split(',')]
                    row = string.split(',')
                    waktu = dt.datetime.now().strftime('%H:%M:%S.%f')
                    rows.insert(0, waktu)
                    writer.writerow(rows)
                    f.flush()
                    
                    dataposisi = int(row[1])
                    arrayposisi.append(dataposisi)
                
                       
            except:
                pass

def sudutaktual ():
    global sudut_max, sudut_min
    sudut_max = ((max(arrayposisi))*-1)
    sudut_min = ((min(arrayposisi))*-1) 

def posisi():
    sudutaktual()
    my_frame_2_spinbox1.delete(0, tkinter.END)
    my_frame_2_spinbox1.insert(0, sudut_max)
    print(sudut_max)

def start():
    data0 = 300
    data1 = 200
    data2 = int((my_frame_2_spinbox2.get()))
    data3 = int((my_frame_2_spinbox3.get()))
    data4 = int((my_frame_2_spinbox4.get()))
    data5 = 2
    data6 = int((my_frame_2_spinbox5.get()))
    data7 = int((my_frame_2_spinbox6.get()))
    data8 = int((my_frame_2_spinbox1.get()))
    data9 = 300
    data10 = 850000
    data11 = 850000
    data12 = 100

    # data0 = 30
    # data1 = 20
    # data2 = 30
    # data3 = 40
    # data4 = 50
    # data5 = 2
    # data6 = 60
    # data7 = 70
    # data8 = 80
    # data9 = 90
    # data10 = 80
    # data11 = 1000
    # data12 = 120

    bid = format(data0,'b')
    var0 = []
    for letter in bid:
        var0.append(int(letter))
    while (len(var0)<30):
        var0[:0]=[0]
    var0.reverse()
    bin0 = bytearray(var0)

    bstatus = format(data1,'b')
    var1 = []
    for letter in bstatus:
        var1.append(int(letter))
    while (len(var1)<30):
        var1[:0]=[0]
    var1.reverse()
    bin1 = bytearray(var1)

    bkp_pos = format(data2,'b')
    var2 = []
    for letter in bkp_pos:
        var2.append(int(letter))
    while (len(var2)<30):
        var2[:0]=[0]
    var2.reverse()
    bin2 = bytearray(var2)

    bkp_kec = format(data3,'b')
    var3 = []
    for letter in bkp_kec:
        var3.append(int(letter))
    while (len(var3)<30):
        var3[:0]=[0]
    var3.reverse()
    bin3 = bytearray(var3)

    bki_kec = format(data4,'b')
    var4 = []
    for letter in bki_kec:
        var4.append(int(letter))
    while (len(var4)<30):
        var4[:0]=[0]
    var4.reverse()
    bin4 = bytearray(var4)

    bsetpid = format(data5,'b')
    var5 = []
    for letter in bsetpid:
        var5.append(int(letter))
    while (len(var5)<30):
        var5[:0]=[0]
    var5.reverse()
    bin5 = bytearray(var5)

    bkec = format(data6,'b')
    var6 = []
    for letter in bkec:
        var6.append(int(letter))
    while (len(var6)<30):
        var6[:0]=[0]
    var6.reverse()
    bin6 = bytearray(var6)

    bacc = format(data7,'b')
    var7 = []
    for letter in bacc:
        var7.append(int(letter))
    while (len(var7)<30):
        var7[:0]=[0]
    var7.reverse()
    bin7 = bytearray(var7)

    bsudut = format(data8,'b')
    var8 = []
    for letter in bsudut:
        var8.append(int(letter))
    while (len(var8)<30):
        var8[:0]=[0]
    var8.reverse()
    bin8 = bytearray(var8)

    btorsi = format(data9,'b')
    var9 = []
    for letter in btorsi:
        var9.append(int(letter))
    while (len(var9)<30):
        var9[:0]=[0]
    var9.reverse()
    bin9 = bytearray(var9)

    bawal = format(data10,'b')
    var10 = []
    for letter in bawal:
        var10.append(int(letter))
    while (len(var10)<30):
        var10[:0]=[0]
    var10.reverse()
    bin10 = bytearray(var10)

    btarget = format(data11,'b')
    var11 = []
    for letter in btarget:
        var11.append(int(letter))
    while (len(var11)<30):
        var11[:0]=[0]
    var11.reverse()
    bin11 = bytearray(var11)

    bstart = format(data12,'b')
    var12 = []
    for letter in bstart:
        var12.append(int(letter))
    while (len(var12)<30):
        var12[:0]=[0]
    var12.reverse()
    bin12 = bytearray(var12)

    k=0
    while k<13 :
        if k == 0:
            arduino.write(bin0)
        elif k == 1:
            arduino.write(bin1)
        elif k == 2:
           arduino.write(bin2)
        elif k == 3:
           arduino.write(bin3)  
        elif k == 4:
           arduino.write(bin4)   
        elif k == 5:
           arduino.write(bin5)
        elif k == 6:
           arduino.write(bin6)
        elif k == 7:
           arduino.write(bin7)  
        elif k == 8:
           arduino.write(bin8) 
        elif k == 9:
           arduino.write(bin9)
        elif k == 10:
           arduino.write(bin10)  
        elif k == 11:
           arduino.write(bin11) 
        elif k == 12:
           arduino.write(bin12) 
        time.sleep(0.1)
        k=k+1

def stop():
    sudutaktual()
    data1 = 200
    data2 = int((my_frame_2_spinbox2.get()))
    data3 = int((my_frame_2_spinbox3.get()))
    data4 = int((my_frame_2_spinbox4.get()))
    data5 = 2
    data6 = int((my_frame_2_spinbox5.get()))
    data7 = int((my_frame_2_spinbox6.get()))
    data8 = int((my_frame_2_spinbox1.get()))
    data9 = int((my_frame_2_spinbox7.get()))*100
    data10 = sudut_min
    data11 = sudut_max
    data12 = 200


    bstatus = format(data1,'b')
    var1 = []
    for letter in bstatus:
        var1.append(int(letter))
    while (len(var1)<30):
        var1[:0]=[0]
    var1.reverse()
    bin1 = bytearray(var1)

    bkp_pos = format(data2,'b')
    var2 = []
    for letter in bkp_pos:
        var2.append(int(letter))
    while (len(var2)<30):
        var2[:0]=[0]
    var2.reverse()
    bin2 = bytearray(var2)

    bkp_kec = format(data3,'b')
    var3 = []
    for letter in bkp_kec:
        var3.append(int(letter))
    while (len(var3)<30):
        var3[:0]=[0]
    var3.reverse()
    bin3 = bytearray(var3)

    bki_kec = format(data4,'b')
    var4 = []
    for letter in bki_kec:
        var4.append(int(letter))
    while (len(var4)<30):
        var4[:0]=[0]
    var4.reverse()
    bin4 = bytearray(var4)

    bsetpid = format(data5,'b')
    var5 = []
    for letter in bsetpid:
        var5.append(int(letter))
    while (len(var5)<30):
        var5[:0]=[0]
    var5.reverse()
    bin5 = bytearray(var5)

    bkec = format(data6,'b')
    var6 = []
    for letter in bkec:
        var6.append(int(letter))
    while (len(var6)<30):
        var6[:0]=[0]
    var6.reverse()
    bin6 = bytearray(var6)

    bacc = format(data7,'b')
    var7 = []
    for letter in bacc:
        var7.append(int(letter))
    while (len(var7)<30):
        var7[:0]=[0]
    var7.reverse()
    bin7 = bytearray(var7)

    bsudut = format(data8,'b')
    var8 = []
    for letter in bsudut:
        var8.append(int(letter))
    while (len(var8)<30):
        var8[:0]=[0]
    var8.reverse()
    bin8 = bytearray(var8)

    btorsi = format(data9,'b')
    var9 = []
    for letter in btorsi:
        var9.append(int(letter))
    while (len(var9)<30):
        var9[:0]=[0]
    var9.reverse()
    bin9 = bytearray(var9)

    bawal = format(data10,'b')
    var10 = []
    for letter in bawal:
        var10.append(int(letter))
    while (len(var10)<30):
        var10[:0]=[0]
    var10.reverse()
    bin10 = bytearray(var10)

    btarget = format(data11,'b')
    var11 = []
    for letter in btarget:
        var11.append(int(letter))
    while (len(var11)<30):
        var11[:0]=[0]
    var11.reverse()
    bin11 = bytearray(var11)

    bstart = format(data12,'b')
    var12 = []
    for letter in bstart:
        var12.append(int(letter))
    while (len(var12)<30):
        var12[:0]=[0]
    var12.reverse()
    bin12 = bytearray(var12)

    k=0
    while k<12 :
        if k == 0:
            arduino.write(bin1)
        elif k == 1:
            arduino.write(bin2)
        elif k == 2:
           arduino.write(bin3)
        elif k == 3:
           arduino.write(bin4)  
        elif k == 4:
           arduino.write(bin5)   
        elif k == 5:
           arduino.write(bin6)
        elif k == 6:
           arduino.write(bin7)
        elif k == 7:
           arduino.write(bin8)  
        elif k == 8:
           arduino.write(bin9) 
        elif k == 9:
           arduino.write(bin10)
        elif k == 10:
           arduino.write(bin11)  
        elif k == 11:
           arduino.write(bin12) 
        time.sleep(0.1)
        k=k+1

    

#====================================================================read data motor 1=====================
part_2 = tkinter.Frame(windows, background='#e2e6e2')
part_2.pack()

my_frame_4 = tkinter.Frame(part_2, width=400, height=625, background='#e2e6e2')
my_frame_4 = tkinter.LabelFrame(part_2, width=200, height=200, text='''Data Reading : Motor 1''', relief='groove', foreground="black",
                                background='#e2e6e2')
my_frame_4.pack(padx=5, pady=5, side=tkinter.LEFT)
my_frame_4.pack_propagate(0)

#================================================BUTTON=========================

connect_btn = tkinter.Button(my_frame_1, text='Connect', width=9, state="disabled", command=connexion)
connect_btn.grid(column=3, row=2)
refresh_btn = tkinter.Button(my_frame_1, text='Refresh', width=9, command=update_coms)
refresh_btn.grid(column=3, row=3)
port_lable = Label(my_frame_1, text="Available Port(s): ", background='#e2e6e2')
port_lable.grid(column=1, row=2, pady=5, padx=5)
port_bd = Label(my_frame_1, text="Baude Rate: ", background='#e2e6e2')
port_bd.grid(column=1, row=3, pady=5, padx=5)
baud_select()
update_coms()
start_btn = tkinter.Button(my_frame_1, text='Start', width=9, command=start)
start_btn.grid(column=3, row=4)
stop_btn = tkinter.Button(my_frame_1, text='Stop', width=9, command=stop)
stop_btn.grid(column=3, row=5)

#=============================================value modification motor 1==========================================
my_frame_2 = tkinter.LabelFrame(part_1, width=350, height=200, text='''Setting Value Exoskeleton''', relief='groove',
                                foreground="black", background='#e2e6e2')
my_frame_2.pack(side=tkinter.LEFT)
my_frame_2.pack_propagate(0)
my_frame_2_bantuan1 = tkinter.Frame(my_frame_2, width=85, height=50, background='#e2e6e2')
my_frame_2_bantuan1.pack(side=tkinter.LEFT)
my_frame_2_bantuan2 = tkinter.Frame(my_frame_2, width=65, height=50, background='#e2e6e2')
my_frame_2_bantuan2.pack(side=tkinter.LEFT)

my_frame_2_bantuan4 = tkinter.Frame(my_frame_2, width=90, height=50, background='#e2e6e2')
my_frame_2_bantuan4.pack(side=tkinter.LEFT)
my_frame_2_bantuan5 = tkinter.Frame(my_frame_2, width=65, height=50, background='#e2e6e2')
my_frame_2_bantuan5.pack(side=tkinter.LEFT)
my_frame_2_bantuan7 = tkinter.Frame(my_frame_2_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_2_bantuan7.pack()
my_frame_2_bantuan7.pack_propagate(0)
my_frame_2_bantuan8 = tkinter.Frame(my_frame_2_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_2_bantuan8.pack()
my_frame_2_bantuan8.pack_propagate(0)
my_frame_2_bantuan9 = tkinter.Frame(my_frame_2_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_2_bantuan9.pack()
my_frame_2_bantuan9.pack_propagate(0)
my_frame_2_bantuan10 = tkinter.Frame(my_frame_2_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_2_bantuan10.pack()
my_frame_2_bantuan10.pack_propagate(0)

my_frame_2_bantuan13 = tkinter.Frame(my_frame_2_bantuan4, width=80, height=25, background='#e2e6e2')
my_frame_2_bantuan13.pack()
my_frame_2_bantuan13.pack_propagate(0)
my_frame_2_bantuan14 = tkinter.Frame(my_frame_2_bantuan4, width=80, height=25, background='#e2e6e2')
my_frame_2_bantuan14.pack()
my_frame_2_bantuan14.pack_propagate(0)
my_frame_2_bantuan15 = tkinter.Frame(my_frame_2_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_2_bantuan15.pack()
my_frame_2_bantuan15.pack_propagate(0)
my_frame_2_bantuan16 = tkinter.Frame(my_frame_2_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_2_bantuan16.pack()
my_frame_2_bantuan16.pack_propagate(0)
my_frame_2_bantuan19 = tkinter.Frame(my_frame_2_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_2_bantuan19.pack()
my_frame_2_bantuan19.pack_propagate(0)
my_frame_2_bantuan22 = tkinter.Frame(my_frame_2_bantuan1, width=85, height=25, background='#e2e6e2')
my_frame_2_bantuan22.pack()
my_frame_2_bantuan22.pack_propagate(0)
my_frame_2_bantuan20 = tkinter.Frame(my_frame_2_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_2_bantuan20.pack()
my_frame_2_bantuan20.pack_propagate(0)
my_frame_2_bantuan25 = tkinter.Frame(my_frame_2_bantuan4, width=90, height=25, background='#e2e6e2')
my_frame_2_bantuan25.pack()
my_frame_2_bantuan25.pack_propagate(0)
my_frame_2_bantuan26 = tkinter.Frame(my_frame_2_bantuan2, width=65, height=25, background='#e2e6e2')
my_frame_2_bantuan26.pack()
my_frame_2_bantuan26.pack_propagate(0)
my_frame_2_bantuan29 = tkinter.Frame(my_frame_2_bantuan5, width=65, height=25, background='#e2e6e2')
my_frame_2_bantuan29.pack()
my_frame_2_bantuan29.pack_propagate(0)


my_frame_2_text1 = tkinter.Label(my_frame_2_bantuan7, text='Sudut', background='#e2e6e2')
my_frame_2_text1.pack(side=tkinter.LEFT)
my_frame_2_text2 = tkinter.Label(my_frame_2_bantuan8, text='Kp Posisi', background='#e2e6e2')
my_frame_2_text2.pack(side=tkinter.LEFT)
my_frame_2_text13 = tkinter.Label(my_frame_2_bantuan19, text='Kp Speed', background='#e2e6e2')
my_frame_2_text13.pack(side=tkinter.LEFT)
my_frame_2_text14 = tkinter.Label(my_frame_2_bantuan22, text='Ki Speed', background='#e2e6e2')
my_frame_2_text14.pack(side=tkinter.LEFT)

my_frame_2_text5 = tkinter.Label(my_frame_2_bantuan13, text='Target Kecepatan', background='#e2e6e2')
my_frame_2_text5.pack(side=tkinter.LEFT)
my_frame_2_text6 = tkinter.Label(my_frame_2_bantuan14, text='Akselerasi', background='#e2e6e2')
my_frame_2_text6.pack(side=tkinter.LEFT)
my_frame_2_text17 = tkinter.Label(my_frame_2_bantuan25, text='Torsi', background='#e2e6e2')
my_frame_2_text17.pack(side=tkinter.LEFT)


my_frame_2_spinbox1 = tkinter.Entry(my_frame_2_bantuan9, from_=None, to=None, width=4)
my_frame_2_spinbox1.configure(justify=tkinter.CENTER)
my_frame_2_spinbox1.pack(pady=1, side=tkinter.LEFT)
my_frame_2_spinbox1.insert(0, "650000")
my_frame_2_spinbox2 = tkinter.Entry(my_frame_2_bantuan10, from_=None, to=None, width=4)
my_frame_2_spinbox2.configure(justify=tkinter.CENTER)
my_frame_2_spinbox2.pack(pady=1, side=tkinter.LEFT)
my_frame_2_spinbox2.insert(0, "100")
my_frame_2_spinbox3 = tkinter.Entry(my_frame_2_bantuan20, from_=None, to=None, width=4)
my_frame_2_spinbox3.configure(justify=tkinter.CENTER)
my_frame_2_spinbox3.pack(pady=1, side=tkinter.LEFT)
my_frame_2_spinbox3.insert(0, "500")
my_frame_2_spinbox4 = tkinter.Entry(my_frame_2_bantuan26, from_=None, to=None, width=4)
my_frame_2_spinbox4.configure(justify=tkinter.CENTER)
my_frame_2_spinbox4.pack(pady=1, side=tkinter.LEFT)
my_frame_2_spinbox4.insert(0, "10")

my_frame_2_spinbox5 = tkinter.Entry(my_frame_2_bantuan15, from_=None, to=None, width=4)
my_frame_2_spinbox5.configure(justify=tkinter.CENTER)
my_frame_2_spinbox5.pack(pady=1, side=tkinter.LEFT)
my_frame_2_spinbox5.insert(0, "100")
my_frame_2_spinbox6 = tkinter.Entry(my_frame_2_bantuan16, from_=None, to=None, width=4)
my_frame_2_spinbox6.configure(justify=tkinter.CENTER)
my_frame_2_spinbox6.pack(pady=1, side=tkinter.LEFT)
my_frame_2_spinbox6.insert(0, "1000")
my_frame_2_spinbox7 = tkinter.Entry(my_frame_2_bantuan29, from_=None, to=None, width=4)
my_frame_2_spinbox7.configure(justify=tkinter.CENTER)
my_frame_2_spinbox7.pack(pady=1, side=tkinter.LEFT)
my_frame_2_spinbox7.insert(0, "300")

def kirim():
    # sudutaktual()
    data0 = 300
    data1 = 200
    data2 = int((my_frame_2_spinbox2.get()))
    data3 = int((my_frame_2_spinbox3.get()))
    data4 = int((my_frame_2_spinbox4.get()))
    data5 = 2
    data6 = int((my_frame_2_spinbox5.get()))
    data7 = int((my_frame_2_spinbox6.get()))
    data8 = int((my_frame_2_spinbox1.get()))
    data9 = 300
    # data10 = sudut_min
    # data11 = sudut_max
    data10 = 850000
    data11 = 600000
    data12 = 100

    # data0 = 100
    # data1 = 200
    # data2 = 100
    # data3 = 500
    # data4 = 10
    # data5 = 2
    # data6 = 1000
    # data7 = 300
    # data8 = 650000
    # data9 = 300
    # data10 = 850000
    # data11 = 600000
    # data12 = 100

    bid = format(data0,'b')
    var0 = []
    for letter in bid:
        var0.append(int(letter))
    while (len(var0)<30):
        var0[:0]=[0]
    var0.reverse()
    bin0 = bytearray(var0)

    bstatus = format(data1,'b')
    var1 = []
    for letter in bstatus:
        var1.append(int(letter))
    while (len(var1)<30):
        var1[:0]=[0]
    var1.reverse()
    bin1 = bytearray(var1)

    bkp_pos = format(data2,'b')
    var2 = []
    for letter in bkp_pos:
        var2.append(int(letter))
    while (len(var2)<30):
        var2[:0]=[0]
    var2.reverse()
    bin2 = bytearray(var2)

    bkp_kec = format(data3,'b')
    var3 = []
    for letter in bkp_kec:
        var3.append(int(letter))
    while (len(var3)<30):
        var3[:0]=[0]
    var3.reverse()
    bin3 = bytearray(var3)

    bki_kec = format(data4,'b')
    var4 = []
    for letter in bki_kec:
        var4.append(int(letter))
    while (len(var4)<30):
        var4[:0]=[0]
    var4.reverse()
    bin4 = bytearray(var4)

    bsetpid = format(data5,'b')
    var5 = []
    for letter in bsetpid:
        var5.append(int(letter))
    while (len(var5)<30):
        var5[:0]=[0]
    var5.reverse()
    bin5 = bytearray(var5)

    bkec = format(data6,'b')
    var6 = []
    for letter in bkec:
        var6.append(int(letter))
    while (len(var6)<30):
        var6[:0]=[0]
    var6.reverse()
    bin6 = bytearray(var6)

    bacc = format(data7,'b')
    var7 = []
    for letter in bacc:
        var7.append(int(letter))
    while (len(var7)<30):
        var7[:0]=[0]
    var7.reverse()
    bin7 = bytearray(var7)

    bsudut = format(data8,'b')
    var8 = []
    for letter in bsudut:
        var8.append(int(letter))
    while (len(var8)<30):
        var8[:0]=[0]
    var8.reverse()
    bin8 = bytearray(var8)

    btorsi = format(data9,'b')
    var9 = []
    for letter in btorsi:
        var9.append(int(letter))
    while (len(var9)<30):
        var9[:0]=[0]
    var9.reverse()
    bin9 = bytearray(var9)

    bawal = format(data10,'b')
    var10 = []
    for letter in bawal:
        var10.append(int(letter))
    while (len(var10)<30):
        var10[:0]=[0]
    var10.reverse()
    bin10 = bytearray(var10)

    btarget = format(data11,'b')
    var11 = []
    for letter in btarget:
        var11.append(int(letter))
    while (len(var11)<30):
        var11[:0]=[0]
    var11.reverse()
    bin11 = bytearray(var11)

    bstart = format(data12,'b')
    var12 = []
    for letter in bstart:
        var12.append(int(letter))
    while (len(var12)<30):
        var12[:0]=[0]
    var12.reverse()
    bin12 = bytearray(var12)

    k=0
    while k<13 :
        if k == 0:
            arduino.write(bin0)
        elif k == 1:
            arduino.write(bin1)
        elif k == 2:
           arduino.write(bin2)
        elif k == 3:
           arduino.write(bin3)  
        elif k == 4:
           arduino.write(bin4)   
        elif k == 5:
           arduino.write(bin5)
        elif k == 6:
           arduino.write(bin6)
        elif k == 7:
           arduino.write(bin7)  
        elif k == 8:
           arduino.write(bin8) 
        elif k == 9:
           arduino.write(bin9)
        elif k == 10:
           arduino.write(bin10)  
        elif k == 11:
           arduino.write(bin11) 
        elif k == 12:
           arduino.write(bin12) 
        time.sleep(0.1)
        k=k+1

def predict():
    TD_Input = [] # Training Data Input
    TD_Target = [] # Training Data Target

    dataset = [[1],[kec,arus]] #fungsi y = x^2+10 dan random

    In_LF = np.zeros([1,2]) #inputnya 2, jml data 10

    for i in range(1):
        temp = dataset[i+1]
    for j in range(2):
        In_LF[i][j] = temp[j]
    
    data_masuk = np.size(In_LF[0])
    datanum = np.size(In_LF)/data_masuk
    TD_Input = In_LF

    Layer1 = 2
    Layer2 = 1
    Layer3 = 1
    Layer4 = 1

    W1_2 = [[-3.530076116406581],[-1.9350437958161328]]  # Weight Input Layer to Hidden Layer 1
    W2_3 = [[2.4756074199418405]] # Weight Hidden Layer 1 to Hidden Layer 2
    W3_4 = [[1.215934318147095]] 

    Th = np.zeros([Layer2+Layer3+Layer4])
    for i in range(int(np.size(Th))):
        Th[i] = 0.1
    
    Input = np.zeros([Layer1])
    OutHidden1 = np.zeros([Layer2])
    OutHidden2 = np.zeros([Layer3])
    OutLayer = np.zeros([Layer4])

    Input = np.zeros([Layer1])
    OutHidden1 = np.zeros([Layer2])
    OutHidden2 = np.zeros([Layer3])
    OutLayer = np.zeros([Layer4])

    for j in range(Layer1):
        Input[j] = TD_Input[0][j]

    # Layer 2
    for j in range(Layer2):
        temp = 0.0
    for k in range(Layer1):
        temp += Input[k]*W1_2[k][j]
    temp -= Th[j]
    OutHidden1[j] = 1/(1+np.exp(-temp))

    for j in range(Layer3):
        temp = 0.0
    for k in range(Layer2):
        temp += OutHidden1[k]*W2_3[k][j]
    temp -= Th[j]
    OutHidden2[j] = 1/(1+np.exp(-temp))

    for j in range(Layer4):
        temp = 0.0
    for k in range(Layer3):
        temp += OutHidden2[k] * W3_4[k][j]
    temp -= Th[j+Layer2+Layer3]
    OutLayer[j] = 1 / (1 + np.exp(-temp))

my_frame_2_button = tkinter.Button(my_frame_2, text='SET1', width=10, command=kirim)
my_frame_2_button.pack()
my_frame_3_button = tkinter.Button(my_frame_2, text='Set Posisi', width=10, command=posisi)
my_frame_3_button.pack()

#========================================================mode test=======================================
my_frame_4 = tkinter.LabelFrame(part_1, width=150, height=200, text='''Test Method''', relief='groove', foreground="black",
                                background='#e2e6e2')
my_frame_4.pack(padx=5, side=tkinter.LEFT)
my_frame_4.pack_propagate(0)

windows.mainloop()
